# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/home/ishaan/Documents/Work/Data/Raw Data.csv',  sep = ';')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 5000)

# %%
Army = df[(df['Career Drawn'] == 'Army' ) |(df['Career Drawn'] == 'indian army' ) | (df['Career Drawn'] == 'commando' ) | (df['Career Drawn'] == 'army' ) | (df['Career Drawn'] == 'soldier') | (df['Career Drawn'] == 'Army officer' ) ]
df.at[Army.index, 'Career Final'] = 'Army'

# %%
Teachers = df[(df['Career Drawn'] == 'Teacher' ) | (df['Career Drawn'] == 'Professor' )]
df.at[Teachers.index, 'Career Final'] = 'Teacher'

# %%
doc = df[(df['Career Drawn'] == 'doctor / nurse') |(df['Career Drawn'] == 'dentist') | (df['Career Drawn'] == 'doctor') | (df['Career Drawn'] == 'Doctor')  ]
df.at[doc.index, 'Career Final'] = 'Doctor'

# %%
Professions = df.groupby('Career Final').count()
Professions['Sno']
# Out:
# Career Final
# Army       113
# Doctor     174
# Teacher    332
# Name: Sno, dtype: int64

# %%
P = df[df['Career Final'] == 'Army']
P.groupby('Career Drawn').count()
# Out:
#               Sno  School Code  State  District  Block  School Name  Type  \
# Career Drawn
# Army           35           35     35        35     35           35    35
# Army officer    4            4      4         4      4            4     4
# army           49           49     49        49     49           49    49
# commando        9            9      9         9      9            9     9
# soldier        10           10     10        10     10           10    10
#
#               School Type  MIS Type  Name of the Student  Gender  Class  \
# Career Drawn
# Army                   35        35                   35      35     35
# Army officer            4         4                    4       4      4
# army                   49        49                   49      49     49
# commando                9         9                    9       9      9
# soldier                10        10                   10      10     10
#
# ...
