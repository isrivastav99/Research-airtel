# %%
import pandas as pd
df = pd.read_csv('/home/ishaan/Documents/Work/oof/Raw Data.csv', sep = ';')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 5000)

# %%
gender_empty = pd.isnull(df['Gender'])
A = df[gender_empty]
A[['Sno','Name of the Student']]
# Out:
#         Sno  Name of the Student
# 250   251.0         Nisarga D.T.
# 320   321.0   Written in kannada
# 811   812.0     ibankyntiew pala
# 813   814.0            ewonmiwar
# 817   818.0  wanpynhunmi nongrum
# 1279    NaN                  NaN

# %%
Teachers_list = df[df['Career Drawn'] == 'Teacher' ]

# %%
Teachers_list
# Out:
#        Sno School Code      State           District       Block  \
# 0      1.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 2      3.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 3      4.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 4      5.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 6      7.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 7      8.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 9     10.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 13    14.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 14    15.0      P11504  Karnataka         Ramanagara  RAMANAGARA
# 25    26.0      P11525  Karnataka         Ramanagara  RAMANAGARA
# 26    27.0      P11525  Karnataka         Ramanagara  RAMANAGARA
# 38    39.0      P11525  Karnataka         Ramanagara  RAMANAGARA
# 39    40.0      P11525  Karnataka         Ramanagara  RAMANAGARA
# ...

# %%
df.dtypes
# Out:
# Sno.                           float64
# School Code                     object
# State                           object
# District                        object
# Block                           object
# School Name                     object
# Type                            object
# School Type                     object
# MIS Type                        object
# Name of the Student             object
# Gender                          object
# Class                          float64
# Stream (if class XI and XII    float64
# Favourite Subject               object
# Favourite Colour                object
# Mother's Occupation             object
# Father's Occupation             object
# Career Drawn                    object
# Career Final                    object
# Career Category                float64
# Specialisation if mentioned     object
# Gender of the drawing           object
# Situation of the as drawn       object
# Remarks if any                  object
# ...

# %%
Professions = df.groupby('Career Drawn').count()
Professions['Sno']
# Out:
# Career Drawn
# Agriculture               1
# Air Force                 3
# Air Hostess              10
# Animal Husbandry          1
# Architect                 5
# Army                     35
# Army officer              4
# Artist                    1
# Astronomy                 1
# Band                      1
# Bank Manager              1
# Biker                     1
# Builder                  12
# Bus Driver                5
# Carpenter/Police          2
# Cartoon                   1
# Chartered Accountant      1
# Cleaner                   1
# Construction Job          1
# Cricketer                13
# D J Player                3
# DJ                        2
# Dancer                    4
# District Collector        1
# Doctor                   63
# Driver                    1
# Engineer                 10
# Environmentalist          8
# Farmer                   29
# Fashion Designer          3
# Film Industry             1
# Florist                   1
# ...

# %%
flor = df[df['Career Drawn'] == 'Florist']
df.at[flor.index, 'Career Category'] = ''

# %%
Florist_list = df[df['Career Category'] == '' ]
Florist_list
# Out:
#     Sno. School Code      State    District       Block           School Name  \
# 59  60.0      P11525  Karnataka  Ramanagara  RAMANAGARA  G Hs Sheshagirihalli
#
#             Type School Type    MIS Type Name of the Student Gender  Class  \
# 59  Co-ed School   Secondary  Sec+Sr Sec             Diya. Y   Girl    8.0
#
#     Stream (if class XI and XII Favourite Subject Favourite Colour  \
# 59                          NaN           Kannada             Blue
#
#    Mother's Occupation Father's Occupation Career Drawn Career Final  \
# 59     Flower Business          Unemployed      Florist          NaN
#
#    Career Category Specialisation if mentioned Gender of the drawing  \
# 59                                         NaN                Female
#
#    Situation of the as drawn  Remarks if any  Unnamed: 24  Unnamed: 25  \
# 59                     Garden            NaN          NaN          NaN
#
#     Unnamed: 26  Unnamed: 27  Unnamed: 28 Unnamed: 29
# ...

# %%
df['Career Drawn'].replace(
    to_replace=['soldier', 'army','Army officer'],
    value='Army',
    inplace=True
)
Defence = df[(df['Career Drawn'] == 'Army' )]
df.at[Defence.index, 'Career Category'] = 'Defence'

# %%
Defence_list = df[df['Career Category'] == 'Defence' ]
Defence_list.Sno.count()
# Out:
# 98

# %%
a = df[df['Career Drawn']=='Army']
a.Sno.count()
# Out:
# 98

# %%
df[pd.isnull(df['Gender of the drawing'])]
# Out:
#          Sno School Code      State            District        Block  \
# 811    812.0      P10548  Meghalaya  West Jaintia Hills  Thadlaskein
# 813    814.0      P10548  Meghalaya  West Jaintia Hills  Thadlaskein
# 817    818.0      P10548  Meghalaya  West Jaintia Hills  Thadlaskein
# 1175  1266.0      P10543  Meghalaya  East Jaintia Hills   Khliehriat
# 1177  1268.0      P10543  Meghalaya  East Jaintia Hills   Khliehriat
# 1179  1270.0      P10543  Meghalaya  East Jaintia Hills   Khliehriat
#
#                                   School Name          Type School Type  \
# 811                    Lummynso LP School SSA  Co-ed School     Primary
# 813                    Lummynso LP School SSA  Co-ed School     Primary
# 817                    Lummynso LP School SSA  Co-ed School     Primary
# 1175  Khatsoripnar Brightstar LP+UPS-EAST-MEG  Co-ed School  Elementary
# 1177  Khatsoripnar Brightstar LP+UPS-EAST-MEG  Co-ed School  Elementary
# ...

# %%
df[-5:]
# Out:
#          Sno School Code      State            District        Block  \
# 1275  1375.0      P10532  Meghalaya  West Jaintia Hills  Thadlaskein
# 1276  1376.0      P10532  Meghalaya  West Jaintia Hills  Thadlaskein
# 1277  1377.0      P10532  Meghalaya  West Jaintia Hills  Thadlaskein
# 1278  1378.0      P10532  Meghalaya  West Jaintia Hills  Thadlaskein
# 1279     NaN         NaN        NaN                 NaN          NaN
#
#                            School Name          Type School Type MIS Type  \
# 1275  Dulong SSA  Upper Primary School  Co-ed School  Elementary  Pri+Ele
# 1276  Dulong SSA  Upper Primary School  Co-ed School  Elementary  Pri+Ele
# 1277  Dulong SSA  Upper Primary School  Co-ed School  Elementary  Pri+Ele
# 1278  Dulong SSA  Upper Primary School  Co-ed School  Elementary  Pri+Ele
# 1279                               NaN           NaN         NaN      NaN
#
#           Name of the Student Gender  Class  Stream (if class XI and XII  \
# ...

# %%
Defence_list
# Out:
#          Sno School Code      State            District        Block  \
# 10      11.0      P11504  Karnataka          Ramanagara   RAMANAGARA
# 35      36.0      P11525  Karnataka          Ramanagara   RAMANAGARA
# 42      43.0      P11525  Karnataka          Ramanagara   RAMANAGARA
# 46      47.0      P11525  Karnataka          Ramanagara   RAMANAGARA
# 62      63.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 63      64.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 64      65.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 82      83.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 83      84.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 84      85.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 85      86.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 87      88.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# 88      89.0      P11530  Karnataka          Ramanagara   RAMANAGARA
# ...
